# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%time
#6分ぐらいかかる
df_aal = pd.read_csv('../02_data_analysis/roi_timeseries/timeseries_aal.csv')
df_ho = pd.read_csv('../02_data_analysis/roi_timeseries/timeseries_ho.csv')

#df_dynamic_aal = pd.read_csv('../02_data_analysis/dynamic_FC/dynamic_aal.csv')
#df_dynamic_ho = pd.read_csv('../02_data_analysis/dynamic_FC/dynamic_ho.csv')

df_subjects_info = pd.read_csv('../02_data_analysis/subjects_info/subjects_info.csv')
# Out:
# CPU times: user 3.08 s, sys: 136 ms, total: 3.22 s
# Wall time: 3.22 s

# %%
df_aal[df_aal['subID'] == 'D0040']['Precentral_L'].plot()
# Out:
# <AxesSubplot:>

# %%
df_subjects_info.Age.hist(bins=40)
df_subjects_info.Age.describe()
# Out:
# <AxesSubplot:>
# count    615.000000
# mean      62.391870
# std       13.469749
# min       33.000000
# 25%       52.000000
# 50%       65.000000
# 75%       74.000000
# max       89.000000
# Name: Age, dtype: float64

# %%
df_subjects_info.Sex.hist(bins=10)
# Out:
# <AxesSubplot:>
# /home/1/16B14626/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/1/16B14626/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/1/16B14626/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/1/16B14626/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 100, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.9987745862851278
# [[1.         0.99938977]
#  [0.99938977 1.        ]]

# %%
x = np.linspace(0, 100, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.9988330791167224
# [[1.         0.99942911]
#  [0.99942911 1.        ]]

# %%
x = np.linspace(0, 10, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.8856754358365692
# [[1.         0.94756231]
#  [0.94756231 1.        ]]

# %%
x = np.linspace(0, 10, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.8741889589300462
# [[1.         0.95208481]
#  [0.95208481 1.        ]]

# %%
x = np.linspace(0, 5, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.4975543205679277
# [[1.         0.81037769]
#  [0.81037769 1.        ]]

# %%
x = np.linspace(0, 5, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.4740186612312106
# [[1.         0.79863072]
#  [0.79863072 1.        ]]

# %%
from sklearn.linear_model import LinearRegression
x = np.linspace(0, 10, 1000)
y = (0.8)*x + 2.5 * np.random.randn(1000) + 25

lr = LinearRegression()
lr.fit(np.array([x]).T,y)

plt.figure(figsize=(6, 6), dpi=80)
plt.scatter(x,y)
plt.grid()                     # グリッド線を表示
plt.show()                     # 図の表示

print('r^2 train data: ', r2_score(x,y))
print('切片: ', lr.intercept_)
print('傾き: ', lr.coef_[0])
# Out:
# LinearRegression()
# r^2 train data:  -68.9149556592652
# 切片:  24.985276376419375
# 傾き:  0.8096237389840822

# %%
lr = LinearRegression()
lr.fit(np.array([y]).T,x)

plt.figure(figsize=(6, 6), dpi=80)
plt.scatter(y,x)
plt.grid()                     # グリッド線を表示
plt.show()                     # 図の表示

print('切片: ', lr.intercept_)
print('傾き: ', lr.coef_[0])
# Out:
# LinearRegression()
# 切片:  -12.121795125079291
# 傾き:  0.5903606581595765

# %%
x = np.linspace(0, 10, 100)
y = (0.8)*x + 2.5 * np.random.randn(100) + 25
#y = (0.8)*x + np.random.randn(1000) + 25

lr = LinearRegression()
lr.fit(np.array([x]).T,y)

plt.figure(figsize=(6, 6), dpi=80)
plt.scatter(x,y)
plt.grid()                     # グリッド線を表示
plt.show()                     # 図の表示

print('切片: ', lr.intercept_)
print('傾き: ', lr.coef_[0])
# Out:
# LinearRegression()
# 切片:  24.84820982790616
# 傾き:  0.8602648485052564

# %%
lr = LinearRegression()
lr.fit(np.array([y]).T,x)

plt.figure(figsize=(6, 6), dpi=80)
plt.scatter(y,x)
plt.grid()                     # グリッド線を表示
plt.show()                     # 図の表示

print('切片: ', lr.intercept_)
print('傾き: ', lr.coef_[0])
# Out:
# LinearRegression()
# 切片:  -12.379019593356528
# 傾き:  0.5962023115486011
