# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%time
#6分ぐらいかかる
df_aal = pd.read_csv('../02_data_analysis/roi_timeseries/timeseries_aal.csv')
df_ho = pd.read_csv('../02_data_analysis/roi_timeseries/timeseries_ho.csv')

#df_dynamic_aal = pd.read_csv('../02_data_analysis/dynamic_FC/dynamic_aal.csv')
#df_dynamic_ho = pd.read_csv('../02_data_analysis/dynamic_FC/dynamic_ho.csv')

df_subjects_info = pd.read_csv('../02_data_analysis/subjects_info/subjects_info.csv')
# Out:
# CPU times: user 3.3 s, sys: 194 ms, total: 3.5 s
# Wall time: 3.5 s

# %%
df_aal[df_aal['subID'] == 'D0040']['Precentral_L'].plot()
# Out:
# <AxesSubplot:>

# %%
df_subjects_info.Age.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df_subjects_info.Sex.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 100, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.9987943392105061
# [[1.         0.99940207]
#  [0.99940207 1.        ]]

# %%
x = np.linspace(0, 100, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.9989643554044703
# [[1.         0.99948964]
#  [0.99948964 1.        ]]

# %%
x = np.linspace(0, 10, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.8716674331240124
# [[1.         0.94334926]
#  [0.94334926 1.        ]]

# %%
x = np.linspace(0, 10, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.8923580147335332
# [[1.        0.9492876]
#  [0.9492876 1.       ]]

# %%
x = np.linspace(0, 5, 1000)
y = x + np.random.randn(1000)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.5256367241321972
# [[1.         0.82054678]
#  [0.82054678 1.        ]]

# %%
x = np.linspace(0, 5, 100)
y = x + np.random.randn(100)
print('r^2 train data: ', r2_score(x,y))
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# r^2 train data:  0.5837977509179897
# [[1.         0.85574626]
#  [0.85574626 1.        ]]
